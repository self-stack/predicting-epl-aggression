# %%
import pandas as pd

# %%
season_18_19 = pd.read_csv('data/premier_league/season-1819_csv.csv')
season_17_18 = pd.read_csv('data/premier_league/season-1718_csv.csv')
season_16_17 = pd.read_csv('data/premier_league/season-1617_csv.csv')
season_15_16 = pd.read_csv('data/premier_league/season-1516_csv.csv')
season_14_15 = pd.read_csv('data/premier_league/season-1415_csv.csv')
season_13_14 = pd.read_csv('data/premier_league/season-1314_csv.csv')
season_12_13 = pd.read_csv('data/premier_league/season-1213_csv.csv')
season_11_12 = pd.read_csv('data/premier_league/season-1112_csv.csv')
season_10_11 = pd.read_csv('data/premier_league/season-1011_csv.csv')
season_09_10 = pd.read_csv('data/premier_league/season-0910_csv.csv')

# %%
seasons = [season_18_19, season_17_18, season_16_17, season_15_16, season_14_15, season_13_14, season_12_13, season_11_12, season_10_11, season_09_10]

# %%
print('Features in each season: ')
len(season_18_19.columns), len(season_17_18.columns), len(season_16_17.columns), len(season_15_16.columns), len(season_14_15.columns), len(season_13_14.columns), len(season_12_13.columns), len(season_11_12.columns), len(season_10_11.columns), len(season_09_10.columns)
# Out:
# Features in each season:
# (62, 65, 65, 65, 68, 68, 74, 71, 71, 71)

# %%
print('Observations in each season: ')
len(season_18_19), len(season_17_18), len(season_16_17), len(season_15_16), len(season_14_15), len(season_13_14), len(season_12_13), len(season_11_12), len(season_10_11), len(season_09_10)
# Out:
# Observations in each season:
# (380, 380, 380, 380, 380, 380, 380, 380, 380, 380)

# %%
ten_season_df = pd.concat(seasons)

# %%
stat_features = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']

# %%
described_features = ['HomeTeam', 'AwayTeam', 'Final_Goals_H', 'Final_Goals_A', 'Final_Result', 'Half_Goals_H', 'Half_Goals_A', 'Half_Result', 'Referee', 'Shots_H', 'Shots_A', 'Target_Shots_H', 'Target_Shots_A', 'Fouls_H', 'Fouls_A', 'Corners_H', 'Corners_A', 'Yellow_H', 'Yellow_A', 'Red_H', 'Red_A']

# %%
game_stats = ten_season_df[stat_features]

# %%
game_stats.Date = pd.to_datetime(game_stats.Date)
game_stats.set_index(game_stats['Date'], inplace=True)
game_stats.drop('Date', axis=1, inplace=True)

# %%
game_stats.columns = described_features

# %%
## dropping object columns
# game_stats.drop(['HomeTeam', 'AwayTeam', 'FTR', 'HTR', 'Referee'], axis=1)

# %%
game_stats.head()
# Out:
#                 HomeTeam        AwayTeam  Final_Goals_H  Final_Goals_A  \
# Date
# 2018-10-08    Man United       Leicester              2              1
# 2018-11-08   Bournemouth         Cardiff              2              0
# 2018-11-08        Fulham  Crystal Palace              0              2
# 2018-11-08  Huddersfield         Chelsea              0              3
# 2018-11-08     Newcastle       Tottenham              1              2
#
#            Final_Result  Half_Goals_H  Half_Goals_A Half_Result     Referee  \
# Date
# 2018-10-08            H             1             0           H  A Marriner
# 2018-11-08            H             1             0           H    K Friend
# 2018-11-08            A             0             1           A      M Dean
# 2018-11-08            A             0             2           A  C Kavanagh
# 2018-11-08            A             1             2           A  M Atkinson
#
# ...

# %%
game_stats['2017']
# Out:
#                   HomeTeam        AwayTeam  Final_Goals_H  Final_Goals_A  \
# Date
# 2017-11-08         Arsenal       Leicester              4              3
# 2017-12-08        Brighton        Man City              0              2
# 2017-12-08         Chelsea         Burnley              2              3
# 2017-12-08  Crystal Palace    Huddersfield              0              3
# 2017-12-08         Everton           Stoke              1              0
# ...                    ...             ...            ...            ...
# 2017-05-21       Liverpool   Middlesbrough              3              0
# 2017-05-21      Man United  Crystal Palace              2              0
# 2017-05-21     Southampton           Stoke              0              1
# 2017-05-21         Swansea       West Brom              2              1
# 2017-05-21         Watford        Man City              0              5
#
#            Final_Result  Half_Goals_H  Half_Goals_A Half_Result      Referee  \
# ...

# %%
game_stats.Final_Result[game_stats.HomeTeam == 'Man United'].value_counts()
# Out:
# H    133
# D     32
# A     25
# Name: Final_Result, dtype: int64

# %%
game_stats.Final_Result[game_stats.AwayTeam == 'Man United'].value_counts()
# Out:
# A    93
# D    49
# H    48
# Name: Final_Result, dtype: int64

# %%
import numpy as np

# %%
manu_wins = np.sum(game_stats.Final_Result[game_stats.HomeTeam == 'Man United'] == 'H') + np.sum(game_stats.Final_Result[game_stats.AwayTeam == 'Man United'] == 'A')

manu_loss = np.sum(game_stats.Final_Result[game_stats.AwayTeam == 'Man United'] == 'H') + np.sum(game_stats.Final_Result[game_stats.HomeTeam == 'Man United'] == 'A')

# %%
manu_away = game_stats.Final_Result[game_stats.AwayTeam == 'Man United']
manu_home = game_stats.Final_Result[game_stats.HomeTeam == 'Man United']

plt.hist(x=[manu_home, manu_away], align='mid')
plt.xticks(ticks=game_stats.Final_Result.unique())
plt.grid(True)
plt.legend(['Home', 'Away'])
plt.title('Man-U W/L/D Away Record');

print('''Bit confusing here. When Away and game results in \'A\' Man-U one that game\n
        Total wins: \t{0}\n
        Total losses: \t {1}'''.format(manu_wins, manu_loss))

# args to include
#labels=['L', 'W', 'D']
# Out:
# Bit confusing here. When Away and game results in 'A' Man-U one that game
#
#         Total wins: 	226
#
#         Total losses: 	 73

# %%
chelsea_wins = np.sum(game_stats.Final_Result[game_stats.HomeTeam == 'Chelsea'] == 'H') + np.sum(game_stats.Final_Result[game_stats.AwayTeam == 'Chelsea'] == 'A')

chelsea_loss = np.sum(game_stats.Final_Result[game_stats.AwayTeam == 'Chelsea'] == 'H') + np.sum(game_stats.Final_Result[game_stats.HomeTeam == 'Chelsea'] == 'A')

# %%
manu_away = game_stats.Final_Result[game_stats.AwayTeam == 'Chelsea']
manu_home = game_stats.Final_Result[game_stats.HomeTeam == 'Chelsea']

plt.hist(x=[manu_home, manu_away], align='mid')
plt.xticks(ticks=game_stats.Final_Result.unique())
plt.grid(True)
plt.legend(['Home', 'Away'])
plt.title('Chelsea W/L/D Away Record');

print('''Bit confusing here. When Away and game results in \'A\' Chelsea one that game\n
        Total wins: \t{0}\n
        Total losses: \t {1}'''.format(chelsea_wins, chelsea_loss))

# args to include
#labels=['L', 'W', 'D']
# Out:
# Bit confusing here. When Away and game results in 'A' Chelsea one that game
#
#         Total wins: 	223
#
#         Total losses: 	 76

# %%
game_stats
# Out:
#                 HomeTeam        AwayTeam  Final_Goals_H  Final_Goals_A  \
# Date
# 2018-10-08    Man United       Leicester              2              1
# 2018-11-08   Bournemouth         Cardiff              2              0
# 2018-11-08        Fulham  Crystal Palace              0              2
# 2018-11-08  Huddersfield         Chelsea              0              3
# 2018-11-08     Newcastle       Tottenham              1              2
# ...                  ...             ...            ...            ...
# 2010-05-09       Everton      Portsmouth              1              0
# 2010-05-09          Hull       Liverpool              0              0
# 2010-05-09    Man United           Stoke              4              0
# 2010-05-09      West Ham        Man City              1              1
# 2010-05-09        Wolves      Sunderland              2              1
#
#            Final_Result  Half_Goals_H  Half_Goals_A Half_Result  \
# Date
# ...

# %%
leicester_wins = np.sum(game_stats.Final_Result[game_stats.HomeTeam == 'Leister'] == 'H') + np.sum(game_stats.Final_Result[game_stats.AwayTeam == 'Chelsea'] == 'A')

leicester_loss = np.sum(game_stats.Final_Result[game_stats.AwayTeam == 'Chelsea'] == 'H') + np.sum(game_stats.Final_Result[game_stats.HomeTeam == 'Chelsea'] == 'A')

# %%
manu_away = game_stats.Final_Result[game_stats.AwayTeam == 'Chelsea']
manu_home = game_stats.Final_Result[game_stats.HomeTeam == 'Chelsea']

plt.hist(x=[manu_home, manu_away], align='mid')
plt.xticks(ticks=game_stats.Final_Result.unique())
plt.grid(True)
plt.legend(['Home', 'Away'])
plt.title('Chelsea W/L/D Away Record');

print('''Bit confusing here. When Away and game results in \'A\' Chelsea one that game\n
        Total wins: \t{0}\n
        Total losses: \t {1}'''.format(chelsea_wins, chelsea_loss))

# args to include
#labels=['L', 'W', 'D']

# %%
game_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3800 entries, 2018-10-08 to 2010-05-09
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HomeTeam        3800 non-null   object
#  1   AwayTeam        3800 non-null   object
#  2   Final_Goals_H   3800 non-null   int64
#  3   Final_Goals_A   3800 non-null   int64
#  4   Final_Result    3800 non-null   object
#  5   Half_Goals_H    3800 non-null   int64
#  6   Half_Goals_A    3800 non-null   int64
#  7   Half_Result     3800 non-null   object
#  8   Referee         3800 non-null   object
#  9   Shots_H         3800 non-null   int64
#  10  Shots_A         3800 non-null   int64
#  11  Target_Shots_H  3800 non-null   int64
#  12  Target_Shots_A  3800 non-null   int64
#  13  Fouls_H         3800 non-null   int64
#  14  Fouls_A         3800 non-null   int64
#  15  Corners_H       3800 non-null   int64
#  16  Corners_A       3800 non-null   int64
# ...

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
max(game_stats.Yellow_H)
# Out:
# 7
